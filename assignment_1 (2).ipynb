# %% [markdown]
#  USING NUMPY

# %%
# Load the Numpy
import numpy as np

# %% [markdown]
# ARRAY MANIPULATION

# %%
# Create a 2 D Array
a = np.array(np.random.randint(20,90,(10,10)))
print(f"The defined array is \n{a}")
print(f" \n The shape of the array is {a.shape}")
# Out:
# The defined array is
# [[59 87 30 74 77 89 58 67 71 63]
#  [36 44 25 77 36 28 66 87 34 23]
#  [61 79 87 32 56 78 67 85 54 53]
#  [86 30 74 81 51 32 61 53 69 53]
#  [78 68 55 37 43 43 78 71 58 64]
#  [27 39 87 78 79 71 77 30 49 68]
#  [36 35 39 67 37 56 56 28 40 84]
#  [28 85 46 58 28 63 44 73 20 45]
#  [58 21 85 41 31 24 76 89 50 57]
#  [53 76 21 57 66 36 70 63 58 84]]
#
#  The shape of the array is (10, 10)

# %%
# Storing the transpose in another matrix object
b =np.transpose(a)
print(f" The transpose of the array is \n{b}")
print(f" \n The shape of the array is {b.shape}")
# Out:
#  The transpose of the array is
# [[59 36 61 86 78 27 36 28 58 53]
#  [87 44 79 30 68 39 35 85 21 76]
#  [30 25 87 74 55 87 39 46 85 21]
#  [74 77 32 81 37 78 67 58 41 57]
#  [77 36 56 51 43 79 37 28 31 66]
#  [89 28 78 32 43 71 56 63 24 36]
#  [58 66 67 61 78 77 56 44 76 70]
#  [67 87 85 53 71 30 28 73 89 63]
#  [71 34 54 69 58 49 40 20 50 58]
#  [63 23 53 53 64 68 84 45 57 84]]
#
#  The shape of the array is (10, 10)

# %%
# 3D Array
random_3d_array = np.array(np.random.randint(20,90,(3,2,4)))
print(f"The defined array is \n{random_3d_array}")
print(f" \n The shape of the array is {random_3d_array.shape}")
# Out:
# The defined array is
# [[[57 68 47 47]
#   [76 36 45 89]]
#
#  [[25 27 33 40]
#   [88 66 66 47]]
#
#  [[52 81 24 77]
#   [71 77 49 20]]]
#
#  The shape of the array is (3, 2, 4)

# %%
 # Storing the transpose of the created 3d array
transposed_3d_array =np.transpose(random_3d_array)
print(f" The transpose of the array is \n{transposed_3d_array}")
print(f" \n The shape of the array is {transposed_3d_array.shape}")
# Out:
#  The transpose of the array is
# [[[57 25 52]
#   [76 88 71]]
#
#  [[68 27 81]
#   [36 66 77]]
#
#  [[47 33 24]
#   [45 66 49]]
#
#  [[47 40 77]
#   [89 47 20]]]
#
#  The shape of the array is (4, 2, 3)

# %% [markdown]
# RESHAPING OF AN ARRAY

# %%
 # Create a two-dimensional array
cohort = np.array(np.random.randint(20,90,(2,8))) # 2D
print(f"The defined array is \n{cohort}")
print(f" \n The shape of the array is {cohort.shape}")
# Out:
# The defined array is
# [[61 81 55 59 60 54 26 60]
#  [22 39 23 69 33 56 30 61]]
#
#  The shape of the array is (2, 8)

# %%
# reshape this to 1-D,2-D or 3-D array
new_shape = (2,4,2)
reshaped_cohort = np.reshape(cohort,new_shape)
print(f"The reshaped array is \n{reshaped_cohort}")
print(f" \n The shape of the array is {reshaped_cohort.shape}")
# Out:
# The reshaped array is
# [[[61 81]
#   [55 59]
#   [60 54]
#   [26 60]]
#
#  [[22 39]
#   [23 69]
#   [33 56]
#   [30 61]]]
#
#  The shape of the array is (2, 4, 2)

# %% [markdown]
# RESIZING AN ARRAY

# %%
# Intialize a 3D array
r3D_cohort = np.array(np.random.randint(20,90,(2,4,6)))
print(f"The defined array is \n{r3D_cohort}")
print(f" \n The shape of the array is {r3D_cohort.shape}")
# Out:
# The defined array is
# [[[59 25 27 28 52 87]
#   [28 31 68 69 58 36]
#   [41 32 36 48 47 48]
#   [31 65 49 69 35 55]]
#
#  [[69 22 50 31 66 58]
#   [45 42 50 89 80 39]
#   [70 80 24 63 30 76]
#   [44 41 76 70 72 29]]]
#
#  The shape of the array is (2, 4, 6)

# %%
# Resize the created 3D array
new_shape = (2,3,6)
resized_r3D_cohort = np.resize(r3D_cohort,new_shape)
print(f"The resized array is \n{resized_r3D_cohort}")
print(f" \n The shape of the array is {resized_r3D_cohort.shape}")
# Out:
# The resized array is
# [[[59 25 27 28 52 87]
#   [28 31 68 69 58 36]
#   [41 32 36 48 47 48]]
#
#  [[31 65 49 69 35 55]
#   [69 22 50 31 66 58]
#   [45 42 50 89 80 39]]]
#
#  The shape of the array is (2, 3, 6)

# %%
r3D_cohort.resize(new_shape)

# %%
r3D_cohort
# Out:
# array([[[59, 25, 27, 28, 52, 87],
#         [28, 31, 68, 69, 58, 36],
#         [41, 32, 36, 48, 47, 48]],
#
#        [[31, 65, 49, 69, 35, 55],
#         [69, 22, 50, 31, 66, 58],
#         [45, 42, 50, 89, 80, 39]]], dtype=int32)

# %% [markdown]
# FLATTENED AN ARRAY

# %%
# Intialize a 3D array
r3D_cohort = np.array(np.random.randint(20,95,(2,4,6)))
print(f"The defined array is \n{r3D_cohort}")
print(f" \n The shape of the array is {r3D_cohort.shape}")
# Out:
# The defined array is
# [[[76 82 43 69 61 24]
#   [86 36 50 94 88 59]
#   [49 24 46 40 21 89]
#   [40 87 74 34 61 74]]
#
#  [[65 79 48 71 90 43]
#   [61 21 77 72 53 85]
#   [75 87 92 64 87 66]
#   [52 24 83 89 39 71]]]
#
#  The shape of the array is (2, 4, 6)

# %%
# Flatten the 3D array
r3D_cohort.flatten()
# Out:
# array([76, 82, 43, 69, 61, 24, 86, 36, 50, 94, 88, 59, 49, 24, 46, 40, 21,
#        89, 40, 87, 74, 34, 61, 74, 65, 79, 48, 71, 90, 43, 61, 21, 77, 72,
#        53, 85, 75, 87, 92, 64, 87, 66, 52, 24, 83, 89, 39, 71],
#       dtype=int32)

# %%
 #Flattens the array in row-major order with 'C'
r3D_cohort.flatten(order='F')
# Out:
# array([76, 65, 86, 61, 49, 75, 40, 52, 82, 79, 36, 21, 24, 87, 87, 24, 43,
#        48, 50, 77, 46, 92, 74, 83, 69, 71, 94, 72, 40, 64, 34, 89, 61, 90,
#        88, 53, 21, 87, 61, 39, 24, 43, 59, 85, 89, 66, 74, 71],
#       dtype=int32)

# %% [markdown]
# INSERTING ALONG AXIS

# %%
a = np.random.randint(20,30,(2,3,4))    # Axis 0 - 2 ; Axis 1 - 3 ; Axis 2 - 4
print(a)
print(a.shape)
# Out:
# [[[26 20 24 24]
#   [22 21 26 20]
#   [22 22 28 21]]
#
#  [[29 23 25 24]
#   [26 22 24 26]
#   [29 21 24 25]]]
# (2, 3, 4)

# %%
#Insert along axis =0
np.insert(a,1,100,axis=0)
# Out:
# array([[[ 26,  20,  24,  24],
#         [ 22,  21,  26,  20],
#         [ 22,  22,  28,  21]],
#
#        [[100, 100, 100, 100],
#         [100, 100, 100, 100],
#         [100, 100, 100, 100]],
#
#        [[ 29,  23,  25,  24],
#         [ 26,  22,  24,  26],
#         [ 29,  21,  24,  25]]], dtype=int32)

# %%
# Insert along axis = 1
np.insert(a,0,50,axis=1)
# Out:
# array([[[50, 50, 50, 50],
#         [26, 20, 24, 24],
#         [22, 21, 26, 20],
#         [22, 22, 28, 21]],
#
#        [[50, 50, 50, 50],
#         [29, 23, 25, 24],
#         [26, 22, 24, 26],
#         [29, 21, 24, 25]]], dtype=int32)

# %%
# Insert along axis=2
np.insert(a,0,200,axis=2)
# Out:
# array([[[200,  26,  20,  24,  24],
#         [200,  22,  21,  26,  20],
#         [200,  22,  22,  28,  21]],
#
#        [[200,  29,  23,  25,  24],
#         [200,  26,  22,  24,  26],
#         [200,  29,  21,  24,  25]]], dtype=int32)

# %%
a = np.random.randint(2,8,(2,4,4))
print(a)
print(a.shape)
# Out:
# [[[2 3 5 7]
#   [6 2 7 5]
#   [3 7 5 6]
#   [2 2 7 5]]
#
#  [[4 4 4 2]
#   [7 3 7 2]
#   [4 3 7 6]
#   [3 7 5 6]]]
# (2, 4, 4)

# %% [markdown]
# APPEND AN ARRAY

# %%
# Append a value to the array. It flattens the array and append -99 to the end
np.append(a, 50)
# Out:
# array([ 2,  3,  5,  7,  6,  2,  7,  5,  3,  7,  5,  6,  2,  2,  7,  5,  4,
#         4,  4,  2,  7,  3,  7,  2,  4,  3,  7,  6,  3,  7,  5,  6, 50])

# %%
# Fix the axis other than axis of appending
b = np.random.randint(2,8,(2,1,4))
print(b)
# Out:
# [[[3 3 5 5]]
#
#  [[7 6 6 6]]]

# %%
print(a)
print(a.shape)
# Out:
# [[[2 3 5 7]
#   [6 2 7 5]
#   [3 7 5 6]
#   [2 2 7 5]]
#
#  [[4 4 4 2]
#   [7 3 7 2]
#   [4 3 7 6]
#   [3 7 5 6]]]
# (2, 4, 4)

# %%
np.append(a,b,axis = 1)
# Out:
# array([[[2, 3, 5, 7],
#         [6, 2, 7, 5],
#         [3, 7, 5, 6],
#         [2, 2, 7, 5],
#         [3, 3, 5, 5]],
#
#        [[4, 4, 4, 2],
#         [7, 3, 7, 2],
#         [4, 3, 7, 6],
#         [3, 7, 5, 6],
#         [7, 6, 6, 6]]], dtype=int32)

# %%
a = np.random.randint(2,4,(2,3,2))
print(a)
print(a.shape)
# Out:
# [[[3 3]
#   [2 2]
#   [2 3]]
#
#  [[3 3]
#   [3 3]
#   [3 3]]]
# (2, 3, 2)

# %% [markdown]
# DELETE

# %%
# Delete along Axis=0
np.delete(a,(0),axis = 0)
# Out:
# array([[[3, 3],
#         [3, 3],
#         [3, 3]]], dtype=int32)

# %%
# Delete along axis=1
np.delete(a,(0,2),axis = 1)
# Out:
# array([[[2, 2]],
#
#        [[3, 3]]], dtype=int32)

# %%
a
# Out:
# array([[[3, 3],
#         [2, 2],
#         [2, 3]],
#
#        [[3, 3],
#         [3, 3],
#         [3, 3]]], dtype=int32)

# %%
# Delete along axis=2
np.delete(a,(0,1),axis = 2)
# Out:
# array([], shape=(2, 3, 0), dtype=int32)

# %% [markdown]
# UNIQUE

# %%
#Initialized array
a = np.random.randint(2,20,(2,4,3))
print(a)
print(a.shape)
# Out:
# [[[ 2 18 11]
#   [ 5 16 11]
#   [15  8 15]
#   [ 3  2  7]]
#
#  [[ 9  4 11]
#   [11 19  6]
#   [ 4 14 17]
#   [ 6 18  8]]]
# (2, 4, 3)

# %%
np.unique(a)
# Out:
# array([ 2,  3,  4,  5,  6,  7,  8,  9, 11, 14, 15, 16, 17, 18, 19],
#       dtype=int32)

# %%
# return_counts= True
np.unique(a,return_counts=True) # Returns tuple
# Out:
# (array([ 2,  3,  4,  5,  6,  7,  8,  9, 11, 14, 15, 16, 17, 18, 19],
#        dtype=int32),
#  array([2, 1, 2, 1, 2, 1, 2, 1, 4, 1, 2, 1, 1, 2, 1]))

# %%
# return_index = True
np.unique(a,return_counts=True,return_index=True)
# Out:
# (array([ 2,  3,  4,  5,  6,  7,  8,  9, 11, 14, 15, 16, 17, 18, 19],
#        dtype=int32),
#  array([ 0,  9, 13,  3, 17, 11,  7, 12,  2, 19,  6,  4, 20,  1, 16]),
#  array([2, 1, 2, 1, 2, 1, 2, 1, 4, 1, 2, 1, 1, 2, 1]))

# %% [markdown]
# COPY AND VIEW

# %%
# Lets take an example of a list
a = [1,2,3,4,5,6]
b = a
b[0] = 10
print(b)
print(a)
# Out:
# [10, 2, 3, 4, 5, 6]
# [10, 2, 3, 4, 5, 6]

# %%
# Lets use the copy method
a = [1,2,3,4,5,6]
b = a.copy()
b[0] = 10
print(b)
print(a)
# Out:
# [10, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]

# %%
a = np.array([2,34,12])
b = a
b[0] = -999
print(b)
print(a)
# Out:
# [-999   34   12]
# [-999   34   12]

# %%
a = np.array([2,34,12])
b = a.copy()
b[0] = -999
print(b)
print(a)
# Out:
# [-999   34   12]
# [ 2 34 12]

# %% [markdown]
# BROADCASTING

# %%
np.arange(3) + 5
# Out:
# array([5, 6, 7])

# %%
np.ones((3,3)) + np.arange(3)
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.],
#        [1., 2., 3.]])

# %%
np.arange(3).reshape((3,1)) + np.arange(3)
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %%
np.arange(3).reshape((3,1)) + np.arange(4)
# Out:
# array([[0, 1, 2, 3],
#        [1, 2, 3, 4],
#        [2, 3, 4, 5]])

# %%
np.arange(2)
# Out:
# array([0, 1])

# %%
#Example 2
a=np.random.randint(2,6,(2,4))
print(a)
b=np.random.randint(1,10,(2,2))
print(b)
# Out:
# [[3 5 5 5]
#  [4 3 5 2]]
# [[6 8]
#  [2 4]]

# %% [markdown]
# MULTIPLY TWO ARRAYS

# %%
a=np.random.randint(2,6,(2,4))
print(a)
b=np.random.randint(0,5,(2,4))
print(b)
# Out:
# [[5 3 2 3]
#  [2 2 3 2]]
# [[4 2 0 4]
#  [3 1 0 0]]

# %%
np.multiply(a,b)
# Out:
# array([[20,  6,  0, 12],
#        [ 6,  2,  0,  0]], dtype=int32)

# %% [markdown]
# DIVIDE TWO ARRAY

# %%
np.divide(a,b)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24100\2626738034.py:1: RuntimeWarning: divide by zero encountered in divide
#   np.divide(a,b)
# array([[1.25      , 1.5       ,        inf, 0.75      ],
#        [0.66666667, 2.        ,        inf,        inf]])

# %%
a=np.random.randint(5,9,(2,4))
print(a)
# Out:
# [[8 7 7 5]
#  [6 6 6 5]]

# %%
print(np.sum(a))
print(np.sum(a,axis=0))
print(np.sum(a,axis=1))
# Out:
# 50
# [14 13 13 10]
# [27 23]

# %%
# Calculate minimum
print(np.min(a))
print(np.min(a,axis=1)) # Across Column
# Out:
# 5
# [5 5]

# %%
# Sort the array
a=np.random.randint(0,20,(3,3))
print(a)
# Out:
# [[ 2 18 15]
#  [ 4  7 12]
#  [ 9  9 19]]

# %%
print(np.sort(a,axis=0)) # Ascending
# Out:
# [[ 2  7 12]
#  [ 4  9 15]
#  [ 9 18 19]]

# %%
print(np.sort(a,axis=1))
# Out:
# [[ 2 15 18]
#  [ 4  7 12]
#  [ 9  9 19]]

# %%
print(-np.sort(-a,axis=1)) # Descending
# Out:
# [[18 15  2]
#  [12  7  4]
#  [19  9  9]]

# %%
sum(np.arange(3)*np.arange(3).transpose())
# Out:
# np.int64(5)

# %% [markdown]
# using pandas

# %%
# Import pandas package
import pandas as pd
import numpy as np

# %% [markdown]
# READ DATA

# %%
# loading csv File
file_path = 'International_T20_Data.csv'
df=pd.read_csv(file_path)

# %%
df.shape
# Out:
# (1417, 27)

# %%
df.head()
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 2  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
#
#   meta.created  meta.revision                    info.dates info.gender  \
# 0   2017-02-18              2  [datetime.date(2017, 2, 17)]        male
# 1   2017-02-19              2  [datetime.date(2017, 2, 19)]        male
# 2   2017-02-23              1  [datetime.date(2017, 2, 22)]        male
# 3   2016-09-12              1   [datetime.date(2016, 9, 5)]        male
# 4   2016-06-19              1  [datetime.date(2016, 6, 18)]        male
#
#   info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0             T20                      5.0           Sri Lanka          20
# 1             T20                      2.0           Sri Lanka          20
# 2             T20                      NaN           Australia          20
# 3             T20                      NaN           Hong Kong          20
# 4             T20                      NaN            Zimbabwe          20
#
#    ... info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 0  ...                  NaN                    NaN                NaN
# 1  ...                  NaN                    NaN                NaN
# 2  ...                 41.0                    NaN                NaN
# 3  ...                 40.0                    NaN                NaN
# 4  ...                  2.0                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 27 columns]

# %%
df.tail(10)
# Out:
#                                                 innings  meta.data_version  \
# 1407  [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 1408  [{'1st innings': {'team': 'United Arab Emirate...                0.9
# 1409  [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 1410  [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 1411  [{'1st innings': {'team': 'United Arab Emirate...                0.9
# 1412  [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 1413  [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 1414  [{'1st innings': {'team': 'Netherlands', 'deli...                0.9
# 1415  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1416  [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
#
#      meta.created  meta.revision                    info.dates info.gender  \
# 1407   2016-03-01              2  [datetime.date(2016, 2, 28)]        male
# 1408   2016-03-01              1  [datetime.date(2016, 2, 29)]        male
# 1409   2016-03-01              2   [datetime.date(2016, 3, 1)]        male
# 1410   2016-03-02              1   [datetime.date(2016, 3, 2)]        male
# 1411   2016-03-03              1   [datetime.date(2016, 3, 3)]        male
# 1412   2016-03-05              2   [datetime.date(2016, 3, 4)]        male
# 1413   2016-03-08              1   [datetime.date(2016, 3, 6)]        male
# 1414   2016-02-03              1   [datetime.date(2016, 2, 3)]        male
# 1415   2016-09-12              1   [datetime.date(2016, 9, 6)]        male
# 1416   2016-09-12              1   [datetime.date(2016, 9, 9)]        male
#
#      info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 1407             T20                      NaN          Bangladesh          20
# 1408             T20                      7.0            Pakistan          20
# 1409             T20                      5.0               India          20
# 1410             T20                      5.0          Bangladesh          20
# 1411             T20                      9.0               India          20
# 1412             T20                      6.0            Pakistan          20
# 1413             T20                      8.0               India          20
# 1414             T20                      NaN         Netherlands          20
# 1415             T20                      NaN           Australia          20
# 1416             T20                      4.0           Australia          20
#
#       ... info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 1407  ...                 23.0                    NaN                NaN
# 1408  ...                  NaN                    NaN                1.0
# 1409  ...                  NaN                    NaN                1.0
# 1410  ...                  NaN                    NaN                NaN
# 1411  ...                  NaN                    NaN                1.0
# 1412  ...                  NaN                    NaN                1.0
# 1413  ...                  NaN                    NaN                NaN
# 1414  ...                 84.0                    NaN                NaN
# 1415  ...                 85.0                    NaN                NaN
# 1416  ...                  NaN                    NaN                NaN
#
#      info.outcome.method info.outcome.result info.outcome.eliminator  \
# 1407                 NaN                 NaN                     NaN
# 1408                 NaN                 NaN                     NaN
# 1409                 NaN                 NaN                     NaN
# 1410                 NaN                 NaN                     NaN
# 1411                 NaN                 NaN                     NaN
# 1412                 NaN                 NaN                     NaN
# 1413                 NaN                 NaN                     NaN
# 1414                 NaN                 NaN                     NaN
# 1415                 NaN                 NaN                     NaN
# 1416                 NaN                 NaN                     NaN
#
#      info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 1407                        NaN                          NaN            NaN
# 1408                        NaN                          NaN            NaN
# 1409                        NaN                          NaN            NaN
# 1410                        NaN                          NaN            NaN
# 1411                        NaN                          NaN            NaN
# 1412                        NaN                          NaN            NaN
# 1413                        NaN                          NaN            NaN
# 1414                        NaN                          NaN            NaN
# 1415                        NaN                          NaN            NaN
# 1416                        NaN                          NaN            NaN
#
#       info.outcome.bowl_out
# 1407                    NaN
# 1408                    NaN
# 1409                    NaN
# 1410                    NaN
# 1411                    NaN
# 1412                    NaN
# 1413                    NaN
# 1414                    NaN
# 1415                    NaN
# 1416                    NaN
#
# [10 rows x 27 columns]

# %% [markdown]
# DESCRIBE

# %%
df.describe()
# Out:
#        meta.data_version  meta.revision  info.outcome.by.wickets   info.overs  \
# count       1.417000e+03    1417.000000               651.000000  1417.000000
# mean        9.000000e-01       1.370501                 6.476190    20.063514
# std         1.110615e-16       0.575198                 1.987802     1.379399
# min         9.000000e-01       1.000000                 1.000000    20.000000
# 25%         9.000000e-01       1.000000                 5.000000    20.000000
# 50%         9.000000e-01       1.000000                 7.000000    20.000000
# 75%         9.000000e-01       2.000000                 8.000000    20.000000
# max         9.000000e-01       5.000000                10.000000    50.000000
#
#        info.outcome.by.runs  info.match_type_number  info.neutral_venue
# count            721.000000              684.000000               328.0
# mean              39.088766              748.774854                 1.0
# std               33.385757              190.050264                 0.0
# min                1.000000              380.000000                 1.0
# 25%               13.000000              627.000000                 1.0
# 50%               30.000000              746.500000                 1.0
# 75%               56.000000              883.250000                 1.0
# max              249.000000             1104.000000                 1.0

# %% [markdown]
# INDEXING AND SLICING

# %%
df.head()
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 2  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
#
#   meta.created  meta.revision                    info.dates info.gender  \
# 0   2017-02-18              2  [datetime.date(2017, 2, 17)]        male
# 1   2017-02-19              2  [datetime.date(2017, 2, 19)]        male
# 2   2017-02-23              1  [datetime.date(2017, 2, 22)]        male
# 3   2016-09-12              1   [datetime.date(2016, 9, 5)]        male
# 4   2016-06-19              1  [datetime.date(2016, 6, 18)]        male
#
#   info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0             T20                      5.0           Sri Lanka          20
# 1             T20                      2.0           Sri Lanka          20
# 2             T20                      NaN           Australia          20
# 3             T20                      NaN           Hong Kong          20
# 4             T20                      NaN            Zimbabwe          20
#
#    ... info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 0  ...                  NaN                    NaN                NaN
# 1  ...                  NaN                    NaN                NaN
# 2  ...                 41.0                    NaN                NaN
# 3  ...                 40.0                    NaN                NaN
# 4  ...                  2.0                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# iloc FUNCTION GETS ROWS AND COLUMN AT PARTICULAR FUNCTION

# %%
#subset which consists of first 8 rows and first 4 columns
df.iloc[:,-3:]
# Out:
#      info.supersubs.South Africa info.bowl_out info.outcome.bowl_out
# 0                            NaN           NaN                   NaN
# 1                            NaN           NaN                   NaN
# 2                            NaN           NaN                   NaN
# 3                            NaN           NaN                   NaN
# 4                            NaN           NaN                   NaN
# ...                          ...           ...                   ...
# 1412                         NaN           NaN                   NaN
# 1413                         NaN           NaN                   NaN
# 1414                         NaN           NaN                   NaN
# 1415                         NaN           NaN                   NaN
# 1416                         NaN           NaN                   NaN
#
# [1417 rows x 3 columns]

# %% [markdown]
# loc DUNCTION GETS ROWS AND COLUMNS WITH PARTICULAR LABELS

# %%
# subset dataframe in which we want to have first 8 rows identified with their rows labels and some named columns
df.loc[50:60,['innings', 'meta.data_version', 'meta.created']]
# Out:
#                                               innings  meta.data_version  \
# 50  [{'1st innings': {'team': 'Oman', 'deliveries'...                0.9
# 51  [{'1st innings': {'team': 'Oman', 'deliveries'...                0.9
# 52  [{'1st innings': {'team': 'Ireland', 'deliveri...                0.9
# 53  [{'1st innings': {'team': 'Ireland', 'deliveri...                0.9
# 54  [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 55  [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 56  [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 57  [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 58  [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 59  [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 60  [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
#
#    meta.created
# 50   2017-01-21
# 51   2017-01-21
# 52   2017-01-21
# 53   2017-01-21
# 54   2020-08-08
# 55   2020-08-08
# 56   2017-04-02
# 57   2017-04-02
# 58   2017-04-08
# 59   2017-04-08
# 60   2017-04-02

# %%
df.columns
# Out:
# Index(['innings', 'meta.data_version', 'meta.created', 'meta.revision',
#        'info.dates', 'info.gender', 'info.match_type',
#        'info.outcome.by.wickets', 'info.outcome.winner', 'info.overs',
#        'info.player_of_match', 'info.teams', 'info.toss.decision',
#        'info.toss.winner', 'info.umpires', 'info.venue', 'info.city',
#        'info.outcome.by.runs', 'info.match_type_number', 'info.neutral_venue',
#        'info.outcome.method', 'info.outcome.result', 'info.outcome.eliminator',
#        'info.supersubs.New Zealand', 'info.supersubs.South Africa',
#        'info.bowl_out', 'info.outcome.bowl_out'],
#       dtype='object')

# %%
df.loc[:,['innings', 'meta.data_version', 'meta.created']]
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1     [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 2     [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
# ...                                                 ...                ...
# 1412  [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 1413  [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 1414  [{'1st innings': {'team': 'Netherlands', 'deli...                0.9
# 1415  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1416  [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
#
#      meta.created
# 0      2017-02-18
# 1      2017-02-19
# 2      2017-02-23
# 3      2016-09-12
# 4      2016-06-19
# ...           ...
# 1412   2016-03-05
# 1413   2016-03-08
# 1414   2016-02-03
# 1415   2016-09-12
# 1416   2016-09-12
#
# [1417 rows x 3 columns]

# %%
df[0:20]
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 2   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 3   [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 4   [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
# 5   [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
# 6   [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 7   [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 8   [{'1st innings': {'team': 'New Zealand', 'deli...                0.9
# 9   [{'1st innings': {'team': 'New Zealand', 'deli...                0.9
# 10  [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 11  [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 12  [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 13  [{'1st innings': {'team': 'England', 'deliveri...                0.9
# 14  [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 15  [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 16  [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 17  [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 18  [{'1st innings': {'team': 'Ireland', 'deliveri...                0.9
# 19  [{'1st innings': {'team': 'Afghanistan', 'deli...                0.9
#
#    meta.created  meta.revision                    info.dates info.gender  \
# 0    2017-02-18              2  [datetime.date(2017, 2, 17)]        male
# 1    2017-02-19              2  [datetime.date(2017, 2, 19)]        male
# 2    2017-02-23              1  [datetime.date(2017, 2, 22)]        male
# 3    2016-09-12              1   [datetime.date(2016, 9, 5)]        male
# 4    2016-06-19              1  [datetime.date(2016, 6, 18)]        male
# 5    2016-06-21              1  [datetime.date(2016, 6, 20)]        male
# 6    2016-06-25              1  [datetime.date(2016, 6, 22)]        male
# 7    2017-01-08              1   [datetime.date(2017, 1, 3)]        male
# 8    2017-01-08              1   [datetime.date(2017, 1, 6)]        male
# 9    2017-01-08              2   [datetime.date(2017, 1, 8)]        male
# 10   2017-02-18              1  [datetime.date(2017, 2, 17)]        male
# 11   2017-06-24              1  [datetime.date(2017, 6, 21)]        male
# 12   2017-06-24              1  [datetime.date(2017, 6, 23)]        male
# 13   2017-06-26              1  [datetime.date(2017, 6, 25)]        male
# 14   2020-08-08              1                ['2017-09-16']        male
# 15   2017-01-28              1  [datetime.date(2017, 1, 26)]        male
# 16   2017-01-31              1  [datetime.date(2017, 1, 29)]        male
# 17   2017-02-13              1   [datetime.date(2017, 2, 1)]        male
# 18   2017-04-02              1   [datetime.date(2017, 3, 8)]        male
# 19   2017-04-02              1  [datetime.date(2017, 3, 10)]        male
#
#    info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0              T20                      5.0           Sri Lanka          20
# 1              T20                      2.0           Sri Lanka          20
# 2              T20                      NaN           Australia          20
# 3              T20                      NaN           Hong Kong          20
# 4              T20                      NaN            Zimbabwe          20
# 5              T20                     10.0               India          20
# 6              T20                      NaN               India          20
# 7              T20                      6.0         New Zealand          20
# 8              T20                      NaN         New Zealand          20
# 9              T20                      NaN         New Zealand          20
# 10             T20                      NaN        South Africa          20
# 11             T20                      9.0             England          20
# 12             T20                      NaN        South Africa          20
# 13             T20                      NaN             England          20
# 14             T20                      NaN         West Indies          20
# 15             T20                      7.0             England          20
# 16             T20                      NaN               India          20
# 17             T20                      NaN               India          20
# 18             T20                      6.0         Afghanistan          20
# 19             T20                      NaN         Afghanistan          20
#
#     ... info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 0   ...                  NaN                    NaN                NaN
# 1   ...                  NaN                    NaN                NaN
# 2   ...                 41.0                    NaN                NaN
# 3   ...                 40.0                    NaN                NaN
# 4   ...                  2.0                    NaN                NaN
# 5   ...                  NaN                    NaN                NaN
# 6   ...                  3.0                    NaN                NaN
# 7   ...                  NaN                    NaN                NaN
# 8   ...                 47.0                    NaN                NaN
# 9   ...                 27.0                    NaN                NaN
# 10  ...                 78.0                    NaN                NaN
# 11  ...                  NaN                    NaN                NaN
# 12  ...                  3.0                    NaN                NaN
# 13  ...                 19.0                    NaN                NaN
# 14  ...                 21.0                  622.0                NaN
# 15  ...                  NaN                    NaN                NaN
# 16  ...                  5.0                    NaN                NaN
# 17  ...                 75.0                    NaN                NaN
# 18  ...                  NaN                    NaN                1.0
# 19  ...                 17.0                    NaN                1.0
#
#    info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                  NaN                 NaN                     NaN
# 1                  NaN                 NaN                     NaN
# 2                  NaN                 NaN                     NaN
# 3                  NaN                 NaN                     NaN
# 4                  NaN                 NaN                     NaN
# 5                  NaN                 NaN                     NaN
# 6                  NaN                 NaN                     NaN
# 7                  NaN                 NaN                     NaN
# 8                  NaN                 NaN                     NaN
# 9                  NaN                 NaN                     NaN
# 10                 NaN                 NaN                     NaN
# 11                 NaN                 NaN                     NaN
# 12                 NaN                 NaN                     NaN
# 13                 NaN                 NaN                     NaN
# 14                 NaN                 NaN                     NaN
# 15                 NaN                 NaN                     NaN
# 16                 NaN                 NaN                     NaN
# 17                 NaN                 NaN                     NaN
# 18                 NaN                 NaN                     NaN
# 19                 D/L                 NaN                     NaN
#
#    info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                         NaN                          NaN            NaN
# 1                         NaN                          NaN            NaN
# 2                         NaN                          NaN            NaN
# 3                         NaN                          NaN            NaN
# 4                         NaN                          NaN            NaN
# 5                         NaN                          NaN            NaN
# 6                         NaN                          NaN            NaN
# 7                         NaN                          NaN            NaN
# 8                         NaN                          NaN            NaN
# 9                         NaN                          NaN            NaN
# 10                        NaN                          NaN            NaN
# 11                        NaN                          NaN            NaN
# 12                        NaN                          NaN            NaN
# 13                        NaN                          NaN            NaN
# 14                        NaN                          NaN            NaN
# 15                        NaN                          NaN            NaN
# 16                        NaN                          NaN            NaN
# 17                        NaN                          NaN            NaN
# 18                        NaN                          NaN            NaN
# 19                        NaN                          NaN            NaN
#
#     info.outcome.bowl_out
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN
# 18                    NaN
# 19                    NaN
#
# [20 rows x 27 columns]

# %%
df[['info.dates', 'info.gender', 'info.match_type',]]
# Out:
#                         info.dates info.gender info.match_type
# 0     [datetime.date(2017, 2, 17)]        male             T20
# 1     [datetime.date(2017, 2, 19)]        male             T20
# 2     [datetime.date(2017, 2, 22)]        male             T20
# 3      [datetime.date(2016, 9, 5)]        male             T20
# 4     [datetime.date(2016, 6, 18)]        male             T20
# ...                            ...         ...             ...
# 1412   [datetime.date(2016, 3, 4)]        male             T20
# 1413   [datetime.date(2016, 3, 6)]        male             T20
# 1414   [datetime.date(2016, 2, 3)]        male             T20
# 1415   [datetime.date(2016, 9, 6)]        male             T20
# 1416   [datetime.date(2016, 9, 9)]        male             T20
#
# [1417 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['innings', 'meta.data_version', 'meta.created', 'meta.revision',
#        'info.dates', 'info.gender', 'info.match_type',
#        'info.outcome.by.wickets', 'info.outcome.winner', 'info.overs',
#        'info.player_of_match', 'info.teams', 'info.toss.decision',
#        'info.toss.winner', 'info.umpires', 'info.venue', 'info.city',
#        'info.outcome.by.runs', 'info.match_type_number', 'info.neutral_venue',
#        'info.outcome.method', 'info.outcome.result', 'info.outcome.eliminator',
#        'info.supersubs.New Zealand', 'info.supersubs.South Africa',
#        'info.bowl_out', 'info.outcome.bowl_out'],
#       dtype='object')

# %% [markdown]
# BOOLEAN INDEXING

# %%
df['info.dates'] == 'en'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1412    False
# 1413    False
# 1414    False
# 1415    False
# 1416    False
# Name: info.dates, Length: 1417, dtype: bool

# %%
# Boolean Indexing
gender = df[df['info.gender'] == 'en']
gender.head()
# Out:
# Empty DataFrame
# Columns: [innings, meta.data_version, meta.created, meta.revision, info.dates, info.gender, info.match_type, info.outcome.by.wickets, info.outcome.winner, info.overs, info.player_of_match, info.teams, info.toss.decision, info.toss.winner, info.umpires, info.venue, info.city, info.outcome.by.runs, info.match_type_number, info.neutral_venue, info.outcome.method, info.outcome.result, info.outcome.eliminator, info.supersubs.New Zealand, info.supersubs.South Africa, info.bowl_out, info.outcome.bowl_out]
# Index: []
#
# [0 rows x 27 columns]

# %%
gender.shape
# Out:
# (0, 27)

# %%
day = df[df['info.dates'] != 'en']
day.head()
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 2  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
#
#   meta.created  meta.revision                    info.dates info.gender  \
# 0   2017-02-18              2  [datetime.date(2017, 2, 17)]        male
# 1   2017-02-19              2  [datetime.date(2017, 2, 19)]        male
# 2   2017-02-23              1  [datetime.date(2017, 2, 22)]        male
# 3   2016-09-12              1   [datetime.date(2016, 9, 5)]        male
# 4   2016-06-19              1  [datetime.date(2016, 6, 18)]        male
#
#   info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0             T20                      5.0           Sri Lanka          20
# 1             T20                      2.0           Sri Lanka          20
# 2             T20                      NaN           Australia          20
# 3             T20                      NaN           Hong Kong          20
# 4             T20                      NaN            Zimbabwe          20
#
#    ... info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 0  ...                  NaN                    NaN                NaN
# 1  ...                  NaN                    NaN                NaN
# 2  ...                 41.0                    NaN                NaN
# 3  ...                 40.0                    NaN                NaN
# 4  ...                  2.0                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# MANIPULATE COLUMNS

# %%
##COLUMN OPERATIONS
df.rename(columns={'info.city':'City'}, inplace=True)

df['Runs_margin'] = df['info.outcome.by.runs']

df.sort_values(by='Runs_margin', ascending=False).head()
# Out:
#                                                innings  meta.data_version  \
# 688  [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 762  [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 384  [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
# 217  [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 147  [{'1st innings': {'team': 'India', 'deliveries...                0.9
#
#     meta.created  meta.revision                    info.dates info.gender  \
# 688   2020-08-26              1                ['2019-12-05']      female
# 762   2013-02-19              1  [datetime.date(2007, 9, 14)]        male
# 384   2019-10-30              2                ['2019-05-05']      female
# 217   2020-06-30              1                ['2018-06-07']      female
# 147   2020-07-06              1                ['2018-06-29']        male
#
#     info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 688             T20                      NaN          Bangladesh          20
# 762             T20                      NaN           Sri Lanka          20
# 384             T20                      NaN            Zimbabwe          20
# 217             T20                      NaN            Pakistan          20
# 147             T20                      NaN               India          20
#
#      ... info.match_type_number info.neutral_venue info.outcome.method  \
# 688  ...                  807.0                NaN                 NaN
# 762  ...                    NaN                1.0                 NaN
# 384  ...                  624.0                NaN                 NaN
# 217  ...                  427.0                NaN                 NaN
# 147  ...                  680.0                NaN                 NaN
#
#     info.outcome.result info.outcome.eliminator info.supersubs.New Zealand  \
# 688                 NaN                     NaN                        NaN
# 762                 NaN                     NaN                        NaN
# 384                 NaN                     NaN                        NaN
# 217                 NaN                     NaN                        NaN
# 147                 NaN                     NaN                        NaN
#
#     info.supersubs.South Africa  info.bowl_out  info.outcome.bowl_out  \
# 688                         NaN            NaN                    NaN
# 762                         NaN            NaN                    NaN
# 384                         NaN            NaN                    NaN
# 217                         NaN            NaN                    NaN
# 147                         NaN            NaN                    NaN
#
#      Runs_margin
# 688        249.0
# 762        172.0
# 384        163.0
# 217        147.0
# 147        143.0
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (1417, 28)

# %%
df['Runs_margin']
# Out:
# 0        NaN
# 1        NaN
# 2       41.0
# 3       40.0
# 4        2.0
#         ...
# 1412     NaN
# 1413     NaN
# 1414    84.0
# 1415    85.0
# 1416     NaN
# Name: Runs_margin, Length: 1417, dtype: float64

# %%
df.head()
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 2  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
#
#   meta.created  meta.revision                    info.dates info.gender  \
# 0   2017-02-18              2  [datetime.date(2017, 2, 17)]        male
# 1   2017-02-19              2  [datetime.date(2017, 2, 19)]        male
# 2   2017-02-23              1  [datetime.date(2017, 2, 22)]        male
# 3   2016-09-12              1   [datetime.date(2016, 9, 5)]        male
# 4   2016-06-19              1  [datetime.date(2016, 6, 18)]        male
#
#   info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0             T20                      5.0           Sri Lanka          20
# 1             T20                      2.0           Sri Lanka          20
# 2             T20                      NaN           Australia          20
# 3             T20                      NaN           Hong Kong          20
# 4             T20                      NaN            Zimbabwe          20
#
#    ... info.match_type_number info.neutral_venue info.outcome.method  \
# 0  ...                    NaN                NaN                 NaN
# 1  ...                    NaN                NaN                 NaN
# 2  ...                    NaN                NaN                 NaN
# 3  ...                    NaN                NaN                 NaN
# 4  ...                    NaN                NaN                 NaN
#
#   info.outcome.result info.outcome.eliminator info.supersubs.New Zealand  \
# 0                 NaN                     NaN                        NaN
# 1                 NaN                     NaN                        NaN
# 2                 NaN                     NaN                        NaN
# 3                 NaN                     NaN                        NaN
# 4                 NaN                     NaN                        NaN
#
#   info.supersubs.South Africa  info.bowl_out  info.outcome.bowl_out  \
# 0                         NaN            NaN                    NaN
# 1                         NaN            NaN                    NaN
# 2                         NaN            NaN                    NaN
# 3                         NaN            NaN                    NaN
# 4                         NaN            NaN                    NaN
#
#    Runs_margin
# 0          NaN
# 1          NaN
# 2         41.0
# 3         40.0
# 4          2.0
#
# [5 rows x 28 columns]

# %% [markdown]
# DROP COLUMN

# %%
df.drop(['meta.data_version'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#                                              innings meta.created  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-18
# 1  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-19
# 2  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-23
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...   2016-09-12
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...   2016-06-19
#
#    meta.revision                    info.dates info.gender info.match_type  \
# 0              2  [datetime.date(2017, 2, 17)]        male             T20
# 1              2  [datetime.date(2017, 2, 19)]        male             T20
# 2              1  [datetime.date(2017, 2, 22)]        male             T20
# 3              1   [datetime.date(2016, 9, 5)]        male             T20
# 4              1  [datetime.date(2016, 6, 18)]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0                      5.0           Sri Lanka          20
# 1                      2.0           Sri Lanka          20
# 2                      NaN           Australia          20
# 3                      NaN           Hong Kong          20
# 4                      NaN            Zimbabwe          20
#
#   info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 0    ['DAS Gunaratne']  ...                    NaN                NaN
# 1    ['DAS Gunaratne']  ...                    NaN                NaN
# 2          ['A Zampa']  ...                    NaN                NaN
# 3                  NaN  ...                    NaN                NaN
# 4     ['E Chigumbura']  ...                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out Runs_margin
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN        41.0
# 3                    NaN        40.0
# 4                    NaN         2.0
#
# [5 rows x 27 columns]

# %%
df.describe()
# Out:
#        meta.revision  info.outcome.by.wickets   info.overs  \
# count    1417.000000               651.000000  1417.000000
# mean        1.370501                 6.476190    20.063514
# std         0.575198                 1.987802     1.379399
# min         1.000000                 1.000000    20.000000
# 25%         1.000000                 5.000000    20.000000
# 50%         1.000000                 7.000000    20.000000
# 75%         2.000000                 8.000000    20.000000
# max         5.000000                10.000000    50.000000
#
#        info.outcome.by.runs  info.match_type_number  info.neutral_venue  \
# count            721.000000              684.000000               328.0
# mean              39.088766              748.774854                 1.0
# std               33.385757              190.050264                 0.0
# min                1.000000              380.000000                 1.0
# 25%               13.000000              627.000000                 1.0
# 50%               30.000000              746.500000                 1.0
# 75%               56.000000              883.250000                 1.0
# max              249.000000             1104.000000                 1.0
#
#        Runs_margin
# count   721.000000
# mean     39.088766
# std      33.385757
# min       1.000000
# 25%      13.000000
# 50%      30.000000
# 75%      56.000000
# max     249.000000

# %%
df.head()
# Out:
#                                              innings meta.created  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-18
# 1  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-19
# 2  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-23
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...   2016-09-12
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...   2016-06-19
#
#    meta.revision                    info.dates info.gender info.match_type  \
# 0              2  [datetime.date(2017, 2, 17)]        male             T20
# 1              2  [datetime.date(2017, 2, 19)]        male             T20
# 2              1  [datetime.date(2017, 2, 22)]        male             T20
# 3              1   [datetime.date(2016, 9, 5)]        male             T20
# 4              1  [datetime.date(2016, 6, 18)]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0                      5.0           Sri Lanka          20
# 1                      2.0           Sri Lanka          20
# 2                      NaN           Australia          20
# 3                      NaN           Hong Kong          20
# 4                      NaN            Zimbabwe          20
#
#   info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 0    ['DAS Gunaratne']  ...                    NaN                NaN
# 1    ['DAS Gunaratne']  ...                    NaN                NaN
# 2          ['A Zampa']  ...                    NaN                NaN
# 3                  NaN  ...                    NaN                NaN
# 4     ['E Chigumbura']  ...                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out Runs_margin
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN        41.0
# 3                    NaN        40.0
# 4                    NaN         2.0
#
# [5 rows x 27 columns]

# %% [markdown]
# BASIC OPERATIONS

# %%
# if null value
df.loc[:1,'innings'] = np.nan

# %%
df.iloc[:5]
# Out:
#                                              innings meta.created  \
# 0                                                NaN   2017-02-18
# 1                                                NaN   2017-02-19
# 2  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-23
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...   2016-09-12
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...   2016-06-19
#
#    meta.revision                    info.dates info.gender info.match_type  \
# 0              2  [datetime.date(2017, 2, 17)]        male             T20
# 1              2  [datetime.date(2017, 2, 19)]        male             T20
# 2              1  [datetime.date(2017, 2, 22)]        male             T20
# 3              1   [datetime.date(2016, 9, 5)]        male             T20
# 4              1  [datetime.date(2016, 6, 18)]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0                      5.0           Sri Lanka          20
# 1                      2.0           Sri Lanka          20
# 2                      NaN           Australia          20
# 3                      NaN           Hong Kong          20
# 4                      NaN            Zimbabwe          20
#
#   info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 0    ['DAS Gunaratne']  ...                    NaN                NaN
# 1    ['DAS Gunaratne']  ...                    NaN                NaN
# 2          ['A Zampa']  ...                    NaN                NaN
# 3                  NaN  ...                    NaN                NaN
# 4     ['E Chigumbura']  ...                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out Runs_margin
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN        41.0
# 3                    NaN        40.0
# 4                    NaN         2.0
#
# [5 rows x 27 columns]

# %%
df.head()
# Out:
#                                              innings meta.created  \
# 0                                                NaN   2017-02-18
# 1                                                NaN   2017-02-19
# 2  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-23
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...   2016-09-12
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...   2016-06-19
#
#    meta.revision                    info.dates info.gender info.match_type  \
# 0              2  [datetime.date(2017, 2, 17)]        male             T20
# 1              2  [datetime.date(2017, 2, 19)]        male             T20
# 2              1  [datetime.date(2017, 2, 22)]        male             T20
# 3              1   [datetime.date(2016, 9, 5)]        male             T20
# 4              1  [datetime.date(2016, 6, 18)]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0                      5.0           Sri Lanka          20
# 1                      2.0           Sri Lanka          20
# 2                      NaN           Australia          20
# 3                      NaN           Hong Kong          20
# 4                      NaN            Zimbabwe          20
#
#   info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 0    ['DAS Gunaratne']  ...                    NaN                NaN
# 1    ['DAS Gunaratne']  ...                    NaN                NaN
# 2          ['A Zampa']  ...                    NaN                NaN
# 3                  NaN  ...                    NaN                NaN
# 4     ['E Chigumbura']  ...                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out Runs_margin
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN        41.0
# 3                    NaN        40.0
# 4                    NaN         2.0
#
# [5 rows x 27 columns]

# %%
df.iloc[:3]
# Out:
#                                              innings meta.created  \
# 0                                                NaN   2017-02-18
# 1                                                NaN   2017-02-19
# 2  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-23
#
#    meta.revision                    info.dates info.gender info.match_type  \
# 0              2  [datetime.date(2017, 2, 17)]        male             T20
# 1              2  [datetime.date(2017, 2, 19)]        male             T20
# 2              1  [datetime.date(2017, 2, 22)]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0                      5.0           Sri Lanka          20
# 1                      2.0           Sri Lanka          20
# 2                      NaN           Australia          20
#
#   info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 0    ['DAS Gunaratne']  ...                    NaN                NaN
# 1    ['DAS Gunaratne']  ...                    NaN                NaN
# 2          ['A Zampa']  ...                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out Runs_margin
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN        41.0
#
# [3 rows x 27 columns]

# %%
df.head()
# Out:
#                                              innings meta.created  \
# 0                                                NaN   2017-02-18
# 1                                                NaN   2017-02-19
# 2  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-23
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...   2016-09-12
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...   2016-06-19
#
#    meta.revision                    info.dates info.gender info.match_type  \
# 0              2  [datetime.date(2017, 2, 17)]        male             T20
# 1              2  [datetime.date(2017, 2, 19)]        male             T20
# 2              1  [datetime.date(2017, 2, 22)]        male             T20
# 3              1   [datetime.date(2016, 9, 5)]        male             T20
# 4              1  [datetime.date(2016, 6, 18)]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0                      5.0           Sri Lanka          20
# 1                      2.0           Sri Lanka          20
# 2                      NaN           Australia          20
# 3                      NaN           Hong Kong          20
# 4                      NaN            Zimbabwe          20
#
#   info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 0    ['DAS Gunaratne']  ...                    NaN                NaN
# 1    ['DAS Gunaratne']  ...                    NaN                NaN
# 2          ['A Zampa']  ...                    NaN                NaN
# 3                  NaN  ...                    NaN                NaN
# 4     ['E Chigumbura']  ...                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out Runs_margin
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN        41.0
# 3                    NaN        40.0
# 4                    NaN         2.0
#
# [5 rows x 27 columns]

# %% [markdown]
# APPLY FUNCTION

# %%
# Suppose we want to convert the column network to uppercase

def to_uppercase(column):
  return column.upper()

# %%
df.head()
# Out:
#                                              innings meta.created  \
# 0                                                NaN   2017-02-18
# 1                                                NaN   2017-02-19
# 2  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-23
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...   2016-09-12
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...   2016-06-19
#
#    meta.revision                    info.dates info.gender info.match_type  \
# 0              2  [datetime.date(2017, 2, 17)]        male             T20
# 1              2  [datetime.date(2017, 2, 19)]        male             T20
# 2              1  [datetime.date(2017, 2, 22)]        male             T20
# 3              1   [datetime.date(2016, 9, 5)]        male             T20
# 4              1  [datetime.date(2016, 6, 18)]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0                      5.0           Sri Lanka          20
# 1                      2.0           Sri Lanka          20
# 2                      NaN           Australia          20
# 3                      NaN           Hong Kong          20
# 4                      NaN            Zimbabwe          20
#
#   info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 0    ['DAS Gunaratne']  ...                    NaN                NaN
# 1    ['DAS Gunaratne']  ...                    NaN                NaN
# 2          ['A Zampa']  ...                    NaN                NaN
# 3                  NaN  ...                    NaN                NaN
# 4     ['E Chigumbura']  ...                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out Runs_margin
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN        41.0
# 3                    NaN        40.0
# 4                    NaN         2.0
#
# [5 rows x 27 columns]

# %% [markdown]
# APPLYING apply() FUNCTION USING LAMBDA FUNCTION

# %%
def add_two_numbers(a,b):
  return a+b

# %%
x = lambda a,b : a+b
x(1,5)
# Out:
# 6

# %%
df.head()
# Out:
#                                              innings meta.created  \
# 0                                                NaN   2017-02-18
# 1                                                NaN   2017-02-19
# 2  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-23
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...   2016-09-12
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...   2016-06-19
#
#    meta.revision                    info.dates info.gender info.match_type  \
# 0              2  [datetime.date(2017, 2, 17)]        male             T20
# 1              2  [datetime.date(2017, 2, 19)]        male             T20
# 2              1  [datetime.date(2017, 2, 22)]        male             T20
# 3              1   [datetime.date(2016, 9, 5)]        male             T20
# 4              1  [datetime.date(2016, 6, 18)]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0                      5.0           Sri Lanka          20
# 1                      2.0           Sri Lanka          20
# 2                      NaN           Australia          20
# 3                      NaN           Hong Kong          20
# 4                      NaN            Zimbabwe          20
#
#   info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 0    ['DAS Gunaratne']  ...                    NaN                NaN
# 1    ['DAS Gunaratne']  ...                    NaN                NaN
# 2          ['A Zampa']  ...                    NaN                NaN
# 3                  NaN  ...                    NaN                NaN
# 4     ['E Chigumbura']  ...                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out Runs_margin
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN        41.0
# 3                    NaN        40.0
# 4                    NaN         2.0
#
# [5 rows x 27 columns]

# %% [markdown]
# SORT SOME DATA COLUMNS IN ASCENDING OR DESCENDING ORDER

# %%
# Sort descending order
df.sort_values('Runs_margin', ascending=False)
# Out:
#                                                 innings meta.created  \
# 688   [{'1st innings': {'team': 'Bangladesh', 'deliv...   2020-08-26
# 762   [{'1st innings': {'team': 'Sri Lanka', 'delive...   2013-02-19
# 384   [{'1st innings': {'team': 'Zimbabwe', 'deliver...   2019-10-30
# 217   [{'1st innings': {'team': 'Pakistan', 'deliver...   2020-06-30
# 147   [{'1st innings': {'team': 'India', 'deliveries...   2020-07-06
# ...                                                 ...          ...
# 1410  [{'1st innings': {'team': 'Pakistan', 'deliver...   2016-03-02
# 1411  [{'1st innings': {'team': 'United Arab Emirate...   2016-03-03
# 1412  [{'1st innings': {'team': 'Sri Lanka', 'delive...   2016-03-05
# 1413  [{'1st innings': {'team': 'Bangladesh', 'deliv...   2016-03-08
# 1416  [{'1st innings': {'team': 'Sri Lanka', 'delive...   2016-09-12
#
#       meta.revision                    info.dates info.gender info.match_type  \
# 688               1                ['2019-12-05']      female             T20
# 762               1  [datetime.date(2007, 9, 14)]        male             T20
# 384               2                ['2019-05-05']      female             T20
# 217               1                ['2018-06-07']      female             T20
# 147               1                ['2018-06-29']        male             T20
# ...             ...                           ...         ...             ...
# 1410              1   [datetime.date(2016, 3, 2)]        male             T20
# 1411              1   [datetime.date(2016, 3, 3)]        male             T20
# 1412              2   [datetime.date(2016, 3, 4)]        male             T20
# 1413              1   [datetime.date(2016, 3, 6)]        male             T20
# 1416              1   [datetime.date(2016, 9, 9)]        male             T20
#
#       info.outcome.by.wickets info.outcome.winner  info.overs  \
# 688                       NaN          Bangladesh          20
# 762                       NaN           Sri Lanka          20
# 384                       NaN            Zimbabwe          20
# 217                       NaN            Pakistan          20
# 147                       NaN               India          20
# ...                       ...                 ...         ...
# 1410                      5.0          Bangladesh          20
# 1411                      9.0               India          20
# 1412                      6.0            Pakistan          20
# 1413                      8.0               India          20
# 1416                      4.0           Australia          20
#
#      info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 688     ['Nigar Sultana']  ...                  807.0                NaN
# 762     ['ST Jayasuriya']  ...                    NaN                1.0
# 384         ['SM Mayers']  ...                  624.0                NaN
# 217          ['Nida Dar']  ...                  427.0                NaN
# 147          ['KL Rahul']  ...                  680.0                NaN
# ...                   ...  ...                    ...                ...
# 1410    ['Soumya Sarkar']  ...                    NaN                NaN
# 1411        ['RG Sharma']  ...                    NaN                1.0
# 1412       ['Umar Akmal']  ...                    NaN                1.0
# 1413         ['S Dhawan']  ...                    NaN                NaN
# 1416       ['GJ Maxwell']  ...                    NaN                NaN
#
#      info.outcome.method info.outcome.result info.outcome.eliminator  \
# 688                  NaN                 NaN                     NaN
# 762                  NaN                 NaN                     NaN
# 384                  NaN                 NaN                     NaN
# 217                  NaN                 NaN                     NaN
# 147                  NaN                 NaN                     NaN
# ...                  ...                 ...                     ...
# 1410                 NaN                 NaN                     NaN
# 1411                 NaN                 NaN                     NaN
# 1412                 NaN                 NaN                     NaN
# 1413                 NaN                 NaN                     NaN
# 1416                 NaN                 NaN                     NaN
#
#      info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 688                         NaN                          NaN            NaN
# 762                         NaN                          NaN            NaN
# 384                         NaN                          NaN            NaN
# 217                         NaN                          NaN            NaN
# 147                         NaN                          NaN            NaN
# ...                         ...                          ...            ...
# 1410                        NaN                          NaN            NaN
# 1411                        NaN                          NaN            NaN
# 1412                        NaN                          NaN            NaN
# 1413                        NaN                          NaN            NaN
# 1416                        NaN                          NaN            NaN
#
#       info.outcome.bowl_out Runs_margin
# 688                     NaN       249.0
# 762                     NaN       172.0
# 384                     NaN       163.0
# 217                     NaN       147.0
# 147                     NaN       143.0
# ...                     ...         ...
# 1410                    NaN         NaN
# 1411                    NaN         NaN
# 1412                    NaN         NaN
# 1413                    NaN         NaN
# 1416                    NaN         NaN
#
# [1417 rows x 27 columns]

# %% [markdown]
# DATE AND TIME OPERATIONS &B FUNCTION

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   innings                      1415 non-null   object
#  1   meta.created                 1417 non-null   object
#  2   meta.revision                1417 non-null   int64
#  3   info.dates                   1417 non-null   object
#  4   info.gender                  1417 non-null   object
#  5   info.match_type              1417 non-null   object
#  6   info.outcome.by.wickets      651 non-null    float64
#  7   info.outcome.winner          1372 non-null   object
#  8   info.overs                   1417 non-null   int64
#  9   info.player_of_match         1255 non-null   object
#  10  info.teams                   1417 non-null   object
#  11  info.toss.decision           1417 non-null   object
#  12  info.toss.winner             1417 non-null   object
#  13  info.umpires                 1395 non-null   object
#  14  info.venue                   1417 non-null   object
#  15  City                         1228 non-null   object
#  16  info.outcome.by.runs         721 non-null    float64
#  17  info.match_type_number       684 non-null    float64
#  18  info.neutral_venue           328 non-null    float64
#  19  info.outcome.method          51 non-null     object
#  20  info.outcome.result          45 non-null     object
#  21  info.outcome.eliminator      16 non-null     object
#  22  info.supersubs.New Zealand   1 non-null      object
#  23  info.supersubs.South Africa  1 non-null      object
#  24  info.bowl_out                2 non-null      object
#  25  info.outcome.bowl_out        2 non-null      object
#  26  Runs_margin                  721 non-null    float64
# dtypes: float64(5), int64(2), object(20)
# memory usage: 299.0+ KB

# %%
df['Runs_margin'][0:5]
# Out:
# 0     NaN
# 1     NaN
# 2    41.0
# 3    40.0
# 4     2.0
# Name: Runs_margin, dtype: float64

# %%
# Import datetime modules
from datetime import datetime
from datetime import date

# %% [markdown]
# strptime() AND Strftime() FUNCTION

# %%
df['Runs_margin'][0:5]
# Out:
# 0     NaN
# 1     NaN
# 2    41.0
# 3    40.0
# 4     2.0
# Name: Runs_margin, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   innings                      1415 non-null   object
#  1   meta.created                 1417 non-null   object
#  2   meta.revision                1417 non-null   int64
#  3   info.dates                   1417 non-null   object
#  4   info.gender                  1417 non-null   object
#  5   info.match_type              1417 non-null   object
#  6   info.outcome.by.wickets      651 non-null    float64
#  7   info.outcome.winner          1372 non-null   object
#  8   info.overs                   1417 non-null   int64
#  9   info.player_of_match         1255 non-null   object
#  10  info.teams                   1417 non-null   object
#  11  info.toss.decision           1417 non-null   object
#  12  info.toss.winner             1417 non-null   object
#  13  info.umpires                 1395 non-null   object
#  14  info.venue                   1417 non-null   object
#  15  City                         1228 non-null   object
#  16  info.outcome.by.runs         721 non-null    float64
#  17  info.match_type_number       684 non-null    float64
#  18  info.neutral_venue           328 non-null    float64
#  19  info.outcome.method          51 non-null     object
#  20  info.outcome.result          45 non-null     object
#  21  info.outcome.eliminator      16 non-null     object
#  22  info.supersubs.New Zealand   1 non-null      object
#  23  info.supersubs.South Africa  1 non-null      object
#  24  info.bowl_out                2 non-null      object
#  25  info.outcome.bowl_out        2 non-null      object
#  26  Runs_margin                  721 non-null    float64
# dtypes: float64(5), int64(2), object(20)
# memory usage: 299.0+ KB

# %%
df.head()
# Out:
#                                              innings meta.created  \
# 0                                                NaN   2017-02-18
# 1                                                NaN   2017-02-19
# 2  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-23
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...   2016-09-12
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...   2016-06-19
#
#    meta.revision                    info.dates info.gender info.match_type  \
# 0              2  [datetime.date(2017, 2, 17)]        male             T20
# 1              2  [datetime.date(2017, 2, 19)]        male             T20
# 2              1  [datetime.date(2017, 2, 22)]        male             T20
# 3              1   [datetime.date(2016, 9, 5)]        male             T20
# 4              1  [datetime.date(2016, 6, 18)]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0                      5.0           Sri Lanka          20
# 1                      2.0           Sri Lanka          20
# 2                      NaN           Australia          20
# 3                      NaN           Hong Kong          20
# 4                      NaN            Zimbabwe          20
#
#   info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 0    ['DAS Gunaratne']  ...                    NaN                NaN
# 1    ['DAS Gunaratne']  ...                    NaN                NaN
# 2          ['A Zampa']  ...                    NaN                NaN
# 3                  NaN  ...                    NaN                NaN
# 4     ['E Chigumbura']  ...                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out Runs_margin
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN        41.0
# 3                    NaN        40.0
# 4                    NaN         2.0
#
# [5 rows x 27 columns]

# %%
df['Runs_margin'][0]
# Out:
# np.float64(nan)

# %%
print(date.today())
print(datetime.now())
# Out:
# 2026-03-06
# 2026-03-06 13:18:52.374155

# %%
from datetime import timedelta
datetime.now() + timedelta(days=1)
# Out:
# datetime.datetime(2026, 3, 7, 13, 18, 54, 79341)

# %%
# operations on datetime
from datetime import timedelta
print(date.today())
print(date.today() - timedelta(days=1))
print(datetime.now() + timedelta(hours=5.5))
print(datetime.now() + timedelta(seconds=60))
# Out:
# 2026-03-06
# 2026-03-05
# 2026-03-06 18:48:54.469990
# 2026-03-06 13:19:54.470455

# %%
print(df['Runs_margin'][0])
print(df['Runs_margin'][5])
# Out:
# nan
# nan

# %%
t1 = pd.to_datetime('1/1/2015 01:00')
t2 = pd.to_datetime('1/1/2015 03:30')

print(pd.Timedelta(t2 - t1).seconds / 3600.0)
# Out:
# 2.5

# %% [markdown]
# BASIC OPERATIONS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   innings                      1415 non-null   object
#  1   meta.created                 1417 non-null   object
#  2   meta.revision                1417 non-null   int64
#  3   info.dates                   1417 non-null   object
#  4   info.gender                  1417 non-null   object
#  5   info.match_type              1417 non-null   object
#  6   info.outcome.by.wickets      651 non-null    float64
#  7   info.outcome.winner          1372 non-null   object
#  8   info.overs                   1417 non-null   int64
#  9   info.player_of_match         1255 non-null   object
#  10  info.teams                   1417 non-null   object
#  11  info.toss.decision           1417 non-null   object
#  12  info.toss.winner             1417 non-null   object
#  13  info.umpires                 1395 non-null   object
#  14  info.venue                   1417 non-null   object
#  15  City                         1228 non-null   object
#  16  info.outcome.by.runs         721 non-null    float64
#  17  info.match_type_number       684 non-null    float64
#  18  info.neutral_venue           328 non-null    float64
#  19  info.outcome.method          51 non-null     object
#  20  info.outcome.result          45 non-null     object
#  21  info.outcome.eliminator      16 non-null     object
#  22  info.supersubs.New Zealand   1 non-null      object
#  23  info.supersubs.South Africa  1 non-null      object
#  24  info.bowl_out                2 non-null      object
#  25  info.outcome.bowl_out        2 non-null      object
#  26  Runs_margin                  721 non-null    float64
# dtypes: float64(5), int64(2), object(20)
# memory usage: 299.0+ KB

# %%
# list of unique values in a column
list(df['Runs_margin'].unique())
# Out:
# [np.float64(nan),
#  np.float64(41.0),
#  np.float64(40.0),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(47.0),
#  np.float64(27.0),
#  np.float64(78.0),
#  np.float64(19.0),
#  np.float64(21.0),
#  np.float64(5.0),
#  np.float64(75.0),
#  np.float64(17.0),
#  np.float64(28.0),
#  np.float64(1.0),
#  np.float64(8.0),
#  np.float64(16.0),
#  np.float64(14.0),
#  np.float64(11.0),
#  np.float64(44.0),
#  np.float64(12.0),
#  np.float64(24.0),
#  np.float64(7.0),
#  np.float64(91.0),
#  np.float64(98.0),
#  np.float64(20.0),
#  np.float64(83.0),
#  np.float64(45.0),
#  np.float64(30.0),
#  np.float64(29.0),
#  np.float64(119.0),
#  np.float64(48.0),
#  np.float64(18.0),
#  np.float64(33.0),
#  np.float64(53.0),
#  np.float64(6.0),
#  np.float64(36.0),
#  np.float64(93.0),
#  np.float64(88.0),
#  np.float64(39.0),
#  np.float64(42.0),
#  np.float64(54.0),
#  np.float64(66.0),
#  np.float64(121.0),
#  np.float64(84.0),
#  np.float64(57.0),
#  np.float64(106.0),
#  np.float64(143.0),
#  np.float64(82.0),
#  np.float64(76.0),
#  np.float64(72.0),
#  np.float64(4.0),
#  np.float64(46.0),
#  np.float64(115.0),
#  np.float64(74.0),
#  np.float64(100.0),
#  np.float64(34.0),
#  np.float64(32.0),
#  np.float64(23.0),
#  np.float64(49.0),
#  np.float64(25.0),
#  np.float64(142.0),
#  np.float64(90.0),
#  np.float64(147.0),
#  np.float64(70.0),
#  np.float64(81.0),
#  np.float64(52.0),
#  np.float64(60.0),
#  np.float64(38.0),
#  np.float64(31.0),
#  np.float64(71.0),
#  np.float64(50.0),
#  np.float64(80.0),
#  np.float64(35.0),
#  np.float64(51.0),
#  np.float64(137.0),
#  np.float64(124.0),
#  np.float64(56.0),
#  np.float64(64.0),
#  np.float64(15.0),
#  np.float64(63.0),
#  np.float64(86.0),
#  np.float64(87.0),
#  np.float64(113.0),
#  np.float64(85.0),
#  np.float64(96.0),
#  np.float64(133.0),
#  np.float64(10.0),
#  np.float64(163.0),
#  np.float64(92.0),
#  np.float64(132.0),
#  np.float64(134.0),
#  np.float64(37.0),
#  np.float64(73.0),
#  np.float64(107.0),
#  np.float64(97.0),
#  np.float64(67.0),
#  np.float64(69.0),
#  np.float64(22.0),
#  np.float64(131.0),
#  np.float64(79.0),
#  np.float64(62.0),
#  np.float64(13.0),
#  np.float64(43.0),
#  np.float64(105.0),
#  np.float64(58.0),
#  np.float64(26.0),
#  np.float64(61.0),
#  np.float64(141.0),
#  np.float64(249.0),
#  np.float64(102.0),
#  np.float64(128.0),
#  np.float64(138.0),
#  np.float64(95.0),
#  np.float64(77.0),
#  np.float64(172.0),
#  np.float64(130.0),
#  np.float64(9.0),
#  np.float64(59.0),
#  np.float64(65.0),
#  np.float64(103.0),
#  np.float64(116.0),
#  np.float64(55.0),
#  np.float64(94.0),
#  np.float64(68.0),
#  np.float64(99.0)]

# %%
list(df['Runs_margin'].unique())
# Out:
# [np.float64(nan),
#  np.float64(41.0),
#  np.float64(40.0),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(47.0),
#  np.float64(27.0),
#  np.float64(78.0),
#  np.float64(19.0),
#  np.float64(21.0),
#  np.float64(5.0),
#  np.float64(75.0),
#  np.float64(17.0),
#  np.float64(28.0),
#  np.float64(1.0),
#  np.float64(8.0),
#  np.float64(16.0),
#  np.float64(14.0),
#  np.float64(11.0),
#  np.float64(44.0),
#  np.float64(12.0),
#  np.float64(24.0),
#  np.float64(7.0),
#  np.float64(91.0),
#  np.float64(98.0),
#  np.float64(20.0),
#  np.float64(83.0),
#  np.float64(45.0),
#  np.float64(30.0),
#  np.float64(29.0),
#  np.float64(119.0),
#  np.float64(48.0),
#  np.float64(18.0),
#  np.float64(33.0),
#  np.float64(53.0),
#  np.float64(6.0),
#  np.float64(36.0),
#  np.float64(93.0),
#  np.float64(88.0),
#  np.float64(39.0),
#  np.float64(42.0),
#  np.float64(54.0),
#  np.float64(66.0),
#  np.float64(121.0),
#  np.float64(84.0),
#  np.float64(57.0),
#  np.float64(106.0),
#  np.float64(143.0),
#  np.float64(82.0),
#  np.float64(76.0),
#  np.float64(72.0),
#  np.float64(4.0),
#  np.float64(46.0),
#  np.float64(115.0),
#  np.float64(74.0),
#  np.float64(100.0),
#  np.float64(34.0),
#  np.float64(32.0),
#  np.float64(23.0),
#  np.float64(49.0),
#  np.float64(25.0),
#  np.float64(142.0),
#  np.float64(90.0),
#  np.float64(147.0),
#  np.float64(70.0),
#  np.float64(81.0),
#  np.float64(52.0),
#  np.float64(60.0),
#  np.float64(38.0),
#  np.float64(31.0),
#  np.float64(71.0),
#  np.float64(50.0),
#  np.float64(80.0),
#  np.float64(35.0),
#  np.float64(51.0),
#  np.float64(137.0),
#  np.float64(124.0),
#  np.float64(56.0),
#  np.float64(64.0),
#  np.float64(15.0),
#  np.float64(63.0),
#  np.float64(86.0),
#  np.float64(87.0),
#  np.float64(113.0),
#  np.float64(85.0),
#  np.float64(96.0),
#  np.float64(133.0),
#  np.float64(10.0),
#  np.float64(163.0),
#  np.float64(92.0),
#  np.float64(132.0),
#  np.float64(134.0),
#  np.float64(37.0),
#  np.float64(73.0),
#  np.float64(107.0),
#  np.float64(97.0),
#  np.float64(67.0),
#  np.float64(69.0),
#  np.float64(22.0),
#  np.float64(131.0),
#  np.float64(79.0),
#  np.float64(62.0),
#  np.float64(13.0),
#  np.float64(43.0),
#  np.float64(105.0),
#  np.float64(58.0),
#  np.float64(26.0),
#  np.float64(61.0),
#  np.float64(141.0),
#  np.float64(249.0),
#  np.float64(102.0),
#  np.float64(128.0),
#  np.float64(138.0),
#  np.float64(95.0),
#  np.float64(77.0),
#  np.float64(172.0),
#  np.float64(130.0),
#  np.float64(9.0),
#  np.float64(59.0),
#  np.float64(65.0),
#  np.float64(103.0),
#  np.float64(116.0),
#  np.float64(55.0),
#  np.float64(94.0),
#  np.float64(68.0),
#  np.float64(99.0)]

# %%
# Counts  number of unique values in column
df.Runs_margin.nunique()
# Out:
# 125

# %%
# Give  counts of  category of variable
df['Runs_margin'].value_counts()
# Out:
# Runs_margin
# 5.0      24
# 14.0     19
# 2.0      18
# 11.0     17
# 17.0     17
#          ..
# 138.0     1
# 128.0     1
# 65.0      1
# 116.0     1
# 99.0      1
# Name: count, Length: 125, dtype: int64

# %%
# Returns series of booleans if a column value = null
df['Runs_margin'].isnull()
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1412     True
# 1413     True
# 1414    False
# 1415    False
# 1416     True
# Name: Runs_margin, Length: 1417, dtype: bool

# %%
df[~df['Runs_margin'].isnull()]
# Out:
#                                                 innings meta.created  \
# 2     [{'1st innings': {'team': 'Australia', 'delive...   2017-02-23
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...   2016-09-12
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...   2016-06-19
# 6     [{'1st innings': {'team': 'India', 'deliveries...   2016-06-25
# 8     [{'1st innings': {'team': 'New Zealand', 'deli...   2017-01-08
# ...                                                 ...          ...
# 1404  [{'1st innings': {'team': 'Sri Lanka', 'delive...   2016-02-25
# 1405  [{'1st innings': {'team': 'Bangladesh', 'deliv...   2016-02-27
# 1407  [{'1st innings': {'team': 'Bangladesh', 'deliv...   2016-03-01
# 1414  [{'1st innings': {'team': 'Netherlands', 'deli...   2016-02-03
# 1415  [{'1st innings': {'team': 'Australia', 'delive...   2016-09-12
#
#       meta.revision                    info.dates info.gender info.match_type  \
# 2                 1  [datetime.date(2017, 2, 22)]        male             T20
# 3                 1   [datetime.date(2016, 9, 5)]        male             T20
# 4                 1  [datetime.date(2016, 6, 18)]        male             T20
# 6                 1  [datetime.date(2016, 6, 22)]        male             T20
# 8                 1   [datetime.date(2017, 1, 6)]        male             T20
# ...             ...                           ...         ...             ...
# 1404              3  [datetime.date(2016, 2, 25)]        male             T20
# 1405              1  [datetime.date(2016, 2, 26)]        male             T20
# 1407              2  [datetime.date(2016, 2, 28)]        male             T20
# 1414              1   [datetime.date(2016, 2, 3)]        male             T20
# 1415              1   [datetime.date(2016, 9, 6)]        male             T20
#
#       info.outcome.by.wickets info.outcome.winner  info.overs  \
# 2                         NaN           Australia          20
# 3                         NaN           Hong Kong          20
# 4                         NaN            Zimbabwe          20
# 6                         NaN               India          20
# 8                         NaN         New Zealand          20
# ...                       ...                 ...         ...
# 1404                      NaN           Sri Lanka          20
# 1405                      NaN          Bangladesh          20
# 1407                      NaN          Bangladesh          20
# 1414                      NaN         Netherlands          20
# 1415                      NaN           Australia          20
#
#       info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 2              ['A Zampa']  ...                    NaN                NaN
# 3                      NaN  ...                    NaN                NaN
# 4         ['E Chigumbura']  ...                    NaN                NaN
# 6            ['KM Jadhav']  ...                    NaN                NaN
# 8              ['C Munro']  ...                    NaN                NaN
# ...                    ...  ...                    ...                ...
# 1404        ['SL Malinga']  ...                    NaN                1.0
# 1405       ['Mahmudullah']  ...                    NaN                NaN
# 1407     ['Sabbir Rahman']  ...                    NaN                NaN
# 1414  ['Mudassar Bukhari']  ...                    NaN                NaN
# 1415        ['GJ Maxwell']  ...                    NaN                NaN
#
#      info.outcome.method info.outcome.result info.outcome.eliminator  \
# 2                    NaN                 NaN                     NaN
# 3                    NaN                 NaN                     NaN
# 4                    NaN                 NaN                     NaN
# 6                    NaN                 NaN                     NaN
# 8                    NaN                 NaN                     NaN
# ...                  ...                 ...                     ...
# 1404                 NaN                 NaN                     NaN
# 1405                 NaN                 NaN                     NaN
# 1407                 NaN                 NaN                     NaN
# 1414                 NaN                 NaN                     NaN
# 1415                 NaN                 NaN                     NaN
#
#      info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 2                           NaN                          NaN            NaN
# 3                           NaN                          NaN            NaN
# 4                           NaN                          NaN            NaN
# 6                           NaN                          NaN            NaN
# 8                           NaN                          NaN            NaN
# ...                         ...                          ...            ...
# 1404                        NaN                          NaN            NaN
# 1405                        NaN                          NaN            NaN
# 1407                        NaN                          NaN            NaN
# 1414                        NaN                          NaN            NaN
# 1415                        NaN                          NaN            NaN
#
#       info.outcome.bowl_out Runs_margin
# 2                       NaN        41.0
# 3                       NaN        40.0
# 4                       NaN         2.0
# 6                       NaN         3.0
# 8                       NaN        47.0
# ...                     ...         ...
# 1404                    NaN        14.0
# 1405                    NaN        51.0
# 1407                    NaN        23.0
# 1414                    NaN        84.0
# 1415                    NaN        85.0
#
# [721 rows x 27 columns]

# %%
# fill the missing values with value -999
df['Runs_margin'].fillna('Not Present',inplace = True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24100\3284250596.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Runs_margin'].fillna('Not Present',inplace = True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_24100\3284250596.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Not Present' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Runs_margin'].fillna('Not Present',inplace = True)

# %%
df.head()
# Out:
#                                              innings meta.created  \
# 0                                                NaN   2017-02-18
# 1                                                NaN   2017-02-19
# 2  [{'1st innings': {'team': 'Australia', 'delive...   2017-02-23
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...   2016-09-12
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...   2016-06-19
#
#    meta.revision                    info.dates info.gender info.match_type  \
# 0              2  [datetime.date(2017, 2, 17)]        male             T20
# 1              2  [datetime.date(2017, 2, 19)]        male             T20
# 2              1  [datetime.date(2017, 2, 22)]        male             T20
# 3              1   [datetime.date(2016, 9, 5)]        male             T20
# 4              1  [datetime.date(2016, 6, 18)]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0                      5.0           Sri Lanka          20
# 1                      2.0           Sri Lanka          20
# 2                      NaN           Australia          20
# 3                      NaN           Hong Kong          20
# 4                      NaN            Zimbabwe          20
#
#   info.player_of_match  ... info.match_type_number info.neutral_venue  \
# 0    ['DAS Gunaratne']  ...                    NaN                NaN
# 1    ['DAS Gunaratne']  ...                    NaN                NaN
# 2          ['A Zampa']  ...                    NaN                NaN
# 3                  NaN  ...                    NaN                NaN
# 4     ['E Chigumbura']  ...                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out  Runs_margin
# 0                    NaN  Not Present
# 1                    NaN  Not Present
# 2                    NaN         41.0
# 3                    NaN         40.0
# 4                    NaN          2.0
#
# [5 rows x 27 columns]

# %% [markdown]
# **matplotlib**

# %%
# Import pandas
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("International_T20_Data.csv")

# %%
df.head()
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 2  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
#
#   meta.created  meta.revision                    info.dates info.gender  \
# 0   2017-02-18              2  [datetime.date(2017, 2, 17)]        male
# 1   2017-02-19              2  [datetime.date(2017, 2, 19)]        male
# 2   2017-02-23              1  [datetime.date(2017, 2, 22)]        male
# 3   2016-09-12              1   [datetime.date(2016, 9, 5)]        male
# 4   2016-06-19              1  [datetime.date(2016, 6, 18)]        male
#
#   info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0             T20                      5.0           Sri Lanka          20
# 1             T20                      2.0           Sri Lanka          20
# 2             T20                      NaN           Australia          20
# 3             T20                      NaN           Hong Kong          20
# 4             T20                      NaN            Zimbabwe          20
#
#    ... info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 0  ...                  NaN                    NaN                NaN
# 1  ...                  NaN                    NaN                NaN
# 2  ...                 41.0                    NaN                NaN
# 3  ...                 40.0                    NaN                NaN
# 4  ...                  2.0                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (1417, 27)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
from datetime import datetime
# Importing matplotlib.pyplot
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.head()
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 2  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
#
#   meta.created  meta.revision                    info.dates info.gender  \
# 0   2017-02-18              2  [datetime.date(2017, 2, 17)]        male
# 1   2017-02-19              2  [datetime.date(2017, 2, 19)]        male
# 2   2017-02-23              1  [datetime.date(2017, 2, 22)]        male
# 3   2016-09-12              1   [datetime.date(2016, 9, 5)]        male
# 4   2016-06-19              1  [datetime.date(2016, 6, 18)]        male
#
#   info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 0             T20                      5.0           Sri Lanka          20
# 1             T20                      2.0           Sri Lanka          20
# 2             T20                      NaN           Australia          20
# 3             T20                      NaN           Hong Kong          20
# 4             T20                      NaN            Zimbabwe          20
#
#    ... info.outcome.by.runs info.match_type_number info.neutral_venue  \
# 0  ...                  NaN                    NaN                NaN
# 1  ...                  NaN                    NaN                NaN
# 2  ...                 41.0                    NaN                NaN
# 3  ...                 40.0                    NaN                NaN
# 4  ...                  2.0                    NaN                NaN
#
#   info.outcome.method info.outcome.result info.outcome.eliminator  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   info.supersubs.New Zealand  info.supersubs.South Africa  info.bowl_out  \
# 0                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 4                        NaN                          NaN            NaN
#
#    info.outcome.bowl_out
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 27 columns]

# %%
df.rename(columns={'info.city':'City'}, inplace=True)
df['Runs_margin'] = df['info.outcome.by.runs']
mon = df["Runs_margin"].value_counts()

# %%
type(mon)
# Out:
# pandas.core.series.Series

# %%
mon.sort_index(inplace=True)

# %%
mon
# Out:
# Runs_margin
# 1.0      16
# 2.0      18
# 3.0      15
# 4.0      15
# 5.0      24
#          ..
# 143.0     2
# 147.0     1
# 163.0     1
# 172.0     1
# 249.0     1
# Name: count, Length: 125, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (10, 5)

# %%
##DATA CLEANING
##-MISSING VALUES
df.isnull().sum()
# df.dropna(inplace=True) # Commenting out to prevent loss of all data

##Removing duplicates
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
##COLUMN OPERATIONS
df.rename(columns={'info.city':'City'}, inplace=True)

df['Runs_margin'] = df['info.outcome.by.runs']

df.sort_values(by='Runs_margin', ascending=False).head()
# Out:
#                                                innings  meta.data_version  \
# 688  [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 762  [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 384  [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
# 217  [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 147  [{'1st innings': {'team': 'India', 'deliveries...                0.9
#
#     meta.created  meta.revision                    info.dates info.gender  \
# 688   2020-08-26              1                ['2019-12-05']      female
# 762   2013-02-19              1  [datetime.date(2007, 9, 14)]        male
# 384   2019-10-30              2                ['2019-05-05']      female
# 217   2020-06-30              1                ['2018-06-07']      female
# 147   2020-07-06              1                ['2018-06-29']        male
#
#     info.match_type  info.outcome.by.wickets info.outcome.winner  info.overs  \
# 688             T20                      NaN          Bangladesh          20
# 762             T20                      NaN           Sri Lanka          20
# 384             T20                      NaN            Zimbabwe          20
# 217             T20                      NaN            Pakistan          20
# 147             T20                      NaN               India          20
#
#      ... info.match_type_number info.neutral_venue info.outcome.method  \
# 688  ...                  807.0                NaN                 NaN
# 762  ...                    NaN                1.0                 NaN
# 384  ...                  624.0                NaN                 NaN
# 217  ...                  427.0                NaN                 NaN
# 147  ...                  680.0                NaN                 NaN
#
#     info.outcome.result info.outcome.eliminator info.supersubs.New Zealand  \
# 688                 NaN                     NaN                        NaN
# 762                 NaN                     NaN                        NaN
# 384                 NaN                     NaN                        NaN
# 217                 NaN                     NaN                        NaN
# 147                 NaN                     NaN                        NaN
#
#     info.supersubs.South Africa  info.bowl_out  info.outcome.bowl_out  \
# 688                         NaN            NaN                    NaN
# 762                         NaN            NaN                    NaN
# 384                         NaN            NaN                    NaN
# 217                         NaN            NaN                    NaN
# 147                         NaN            NaN                    NaN
#
#      Runs_margin
# 688        249.0
# 762        172.0
# 384        163.0
# 217        147.0
# 147        143.0
#
# [5 rows x 28 columns]

# %%
# Fix: Convert 'info.outcome.by.runs' to numeric, coercing errors
df['info.outcome.by.runs'] = pd.to_numeric(df['info.outcome.by.runs'], errors='coerce')

##Filtering Data
df[df['info.gender'] == 'male']
df[df['info.outcome.by.runs'] > 50]
df.loc[:, ['City','info.venue']]
# Out:
#              City                               info.venue
# 0             NaN                 Melbourne Cricket Ground
# 1        Victoria           Simonds Stadium, South Geelong
# 2             NaN                            Adelaide Oval
# 3     Londonderry        Bready Cricket Club, Magheramason
# 4             NaN                       Harare Sports Club
# ...           ...                                      ...
# 1412       Mirpur            Shere Bangla National Stadium
# 1413       Mirpur            Shere Bangla National Stadium
# 1414        Dubai                              ICC Academy
# 1415          NaN  Pallekele International Cricket Stadium
# 1416      Colombo                      R Premadasa Stadium
#
# [1417 rows x 2 columns]

# %%
#GroupBy Operations

##Matches per city
df.groupby('City').size()

##Average run margin by venue
df.groupby('info.venue')['info.outcome.by.runs'].mean()

##Matches won by each team
df['info.outcome.winner'].value_counts()
# Out:
# info.outcome.winner
# Australia                   132
# England                     130
# India                       121
# Pakistan                    117
# South Africa                101
# New Zealand                  97
# West Indies                  85
# Sri Lanka                    69
# Afghanistan                  51
# Bangladesh                   50
# Ireland                      48
# Netherlands                  38
# Scotland                     33
# United Arab Emirates         25
# Namibia                      25
# Zimbabwe                     22
# Nepal                        22
# Papua New Guinea             21
# Thailand                     17
# Hong Kong                    17
# Malaysia                     15
# Oman                         14
# Germany                      13
# Kenya                        11
# Singapore                     9
# Canada                        8
# Jersey                        6
# Uganda                        6
# United States of America      5
# China                         5
# Spain                         5
# Vanuatu                       5
# Bermuda                       4
# Belgium                       3
# Kuwait                        3
# Guernsey                      3
# Japan                         3
# Rwanda                        3
# Sierra Leone                  3
# Nigeria                       3
# Romania                       2
# Maldives                      2
# Botswana                      2
# Qatar                         2
# Tanzania                      2
# Italy                         2
# Denmark                       2
# Indonesia                     2
# Mozambique                    1
# ICC World XI                  1
# Malawi                        1
# Philippines                   1
# Samoa                         1
# Portugal                      1
# Bahrain                       1
# Bulgaria                      1
# Name: count, dtype: int64

# %%
runs = np.array(df['info.outcome.by.runs'])

np.mean(runs)
np.median(runs)
np.std(runs)
np.var(runs)
np.max(runs)
np.min(runs)
np.random.choice(runs,10)
# Out:
# array([23., 94., nan, nan, nan, 10., 82., nan, nan, nan])

# %%
#Pivot Table
pd.pivot_table(df,
               values='info.outcome.by.runs',
               index='City',
               aggfunc=np.mean)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24100\1814473021.py:2: FutureWarning: The provided callable <function mean at 0x000001B7B46E5080> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(df,
#              info.outcome.by.runs
# City
# Abu Dhabi               26.318182
# Adelaide               134.000000
# Ahmedabad               11.000000
# Al Amarat               46.666667
# Almeria                 58.000000
# ...                           ...
# Utrecht                 26.000000
# Victoria                 8.000000
# Walferdange             57.666667
# Wellington              45.428571
# Windhoek                92.833333
#
# [128 rows x 1 columns]

# %% [markdown]
# MATPLOTLIB VISUALIZATIONS

# %% [markdown]
# BAR CHART

# %%
teams = df['info.outcome.winner'].value_counts().head(10)
plt.figure(figsize=(10,6))
plt.bar(teams.index, teams.values)
plt.xticks(rotation=90)
plt.title("Top Teams by Wins")
plt.show()

# %% [markdown]
# HISTOGRAM

# %%
plt.hist(df['info.outcome.by.runs'], bins=20)
plt.title("Run Margin Distribution")
plt.xlabel("Runs")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# PIE CHART

# %%
gender = df[df['info.gender'].isin(['male', 'female'])]['info.gender'].value_counts()
plt.pie(gender.values, labels=gender.index, autopct='%1.1f%%')
plt.title("Match Distribution by Gender")
plt.show()

# %% [markdown]
# **seaborn**

# %%
import seaborn as sns

# %% [markdown]
# COUNT PLOT

# %%
plt.figure(figsize=(12, 6))
toss_decisions = df['info.toss.decision'].value_counts()
plt.bar(toss_decisions.index, toss_decisions.values, width=0.6) # Adjust 'width' as desired
plt.title("Toss Decisions")
plt.xlabel("Decision")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# BOX PLOT

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df[df['info.gender'].isin(['male', 'female'])]['info.gender'], y=df['info.outcome.by.runs'], width=0.5)
plt.title("Distribution of Run Margins by Gender")
plt.xlabel("Gender")
plt.ylabel("Run Margin")
plt.show()

# %% [markdown]
# MULTIPLE LINE PLOT IN SAME FIGURE

# %%
plt.figure(figsize=(8,5))

df['info.overs_numeric'] = pd.to_numeric(df['info.overs'], errors='coerce')
df['meta.revision_numeric'] = pd.to_numeric(df['meta.revision'], errors='coerce')

plt.plot(df['info.overs_numeric'].dropna(), label="Overs")
plt.plot(df['meta.revision_numeric'].dropna(), label="Revision")

plt.legend()
plt.title("Multiple Line Plot")

plt.show()

# %% [markdown]
# VIOLIN PLOT

# %%
sns.violinplot(x=df[df['info.gender'].isin(['male', 'female'])]['info.gender'], y='info.outcome.by.runs', data=df, width=0.8)
plt.xlabel("Gender")
plt.title("Distribution of Run Margins by Gender (Violin Plot)")
plt.show()
